# %%
from pycocotools.coco import COCO

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python train.py --data trash.yaml --img-size 512 512  --cfg hub/yolov5x6.yaml --weights yolov5x6.pt --batch-size 32 --name yolov5x6_512_sgd
# !python train.py --data trash.yaml --img-size 1024 1024  --cfg ./models/hub/yolov5x6.yaml --weights yolov5x6.pt --batch-size 8 --name yolov5x6_1024_sgd
# Out:
# github: skipping check (Docker image)
# YOLOv5 🚀 v5.0-96-g36b0a9e torch 1.7.1+cu101 CUDA:0 (Tesla P40, 24451.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='./models/hub/yolov5x6.yaml', data='./data/trash.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov5x6_1024_sgd', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5x6_1024_sgd', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='yolov5x6.pt', workers=4, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python test.py --data trash.yaml --weights ./runs/train/yolov5x6_512_sgd2/weights/best.pt --img-size 512 --batch-size 1 --name yolov5x6_512_sgd2 --task test --save-json
# Out:
# Namespace(augment=False, batch_size=1, conf_thres=0.05, data='./data/trash.yaml', device='', exist_ok=False, img_size=512, iou_thres=0.6, name='yolov5x6_512_sgd2', project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='test', verbose=False, weights=['./runs/train/yolov5x6_512_sgd2/weights/best.pt'])
# YOLOv5 🚀 v5.0-96-g36b0a9e torch 1.7.1+cu101 CUDA:0 (Tesla P40, 24451.875MB)
#
# Fusing layers...
# Model Summary: 606 layers, 141092272 parameters, 0 gradients, 221.4 GFLOPS
# test: Scanning '../input/test.cache' images and labels... 0 found, 837 missing,
#                Class      Images      Labels           P           R      mAP@.5loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# batch_01_vt/0008.jpg
# ou :  1
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# batch_02_vt/1629.jpg
# ou :  6
# ...

# %%
# !python detect.py --source ../input/test.txt --weights ./runs/train/yolov5x6_1024_sgd/weights/best_69.pt --img-size 1024 --name yolov5s_512_adam_ms --conf-thres 0.001 --iou-thres 0.6
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.001, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=1024, iou_thres=0.6, line_thickness=3, name='yolov5s_512_adam_ms', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='../input/test.txt', update=False, view_img=False, weights=['./runs/train/yolov5x6_1024_sgd/weights/best_69.pt'])
# YOLOv5 🚀 v5.0-96-g36b0a9e torch 1.7.1+cu101 CUDA:0 (Tesla P40, 24451.875MB)
#
# Overriding model.yaml nc=80 with nc=11
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Focus                     [3, 80, 3]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  1    309120  models.common.C3                        [160, 160, 4]
# ...
