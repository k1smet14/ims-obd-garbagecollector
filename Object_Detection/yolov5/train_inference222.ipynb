# %%
from pycocotools.coco import COCO

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python train.py --data trash.yaml --img-size 512 512  --cfg hub/yolov5x6.yaml --weights yolov5x6.pt --batch-size 32 --name yolov5x6_512_sgd
# !python train.py --data trash.yaml --img-size 1024 1024  --cfg ./models/yolov5s.yaml --weights yolov5s.pt --batch-size 32 --name yolov5s_1024_adam_ms --multi-scale --epochs 80
# Out:
# github: skipping check (Docker image)
# YOLOv5 🚀 v5.0-96-g36b0a9e torch 1.7.1+cu101 CUDA:0 (Tesla P40, 24451.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='./models/yolov5s.yaml', data='./data/trash.yaml', device='', entity=None, epochs=80, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=True, name='yolov5s_1024_adam_ms', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5s_1024_adam_ms3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov5s.pt', workers=4, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --source ../input/test.txt --weights ./runs/train/yolov5x6_1024_sgd/weights/best_83.pt --img-size 512 --name yolov5x6_1024_sgd --conf-thres 0.0 --iou-thres 0.6
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.0, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=512, iou_thres=0.6, line_thickness=3, name='yolov5x6_1024_sgd', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='../input/test.txt', update=False, view_img=False, weights=['./runs/train/yolov5x6_1024_sgd/weights/best_83.pt'])
# YOLOv5 🚀 v5.0-96-g36b0a9e torch 1.7.1+cu101 CUDA:0 (Tesla P40, 24451.875MB)
#
# Overriding model.yaml nc=80 with nc=11
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Focus                     [3, 80, 3]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  1    309120  models.common.C3                        [160, 160, 4]
# ...

# %%
# !python detect.py --source ../input/test.txt --weights ./runs/train/yolov5x6_512_sgd2/weights/best.pt --img-size 512 --name yolov5x6_512_sgd2 --conf-thres 0.001 --iou-thres 0.6
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.001, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=512, iou_thres=0.6, line_thickness=3, name='yolov5x6_512_sgd2', nosave=False, project='runs/detect', save_conf=True, save_crop=False, save_txt=True, source='../input/test.txt', update=False, view_img=False, weights=['./runs/train/yolov5x6_512_sgd2/weights/best.pt'])
# YOLOv5 🚀 v5.0-96-g36b0a9e torch 1.7.1+cu101 CUDA:0 (Tesla P40, 24451.875MB)
#
# Overriding model.yaml nc=80 with nc=11
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Focus                     [3, 80, 3]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  1    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
# ...
